# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

nama_file = 'heart.csv'
column_names = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
                'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']

df = pd.read_csv(nama_file, header=1, names=column_names, na_values='?')

print("5 baris data pertama:")
print(df.head())
# Out:
# 5 baris data pertama:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   37    1   2       130   250    0        1      187      0      3.5      0
# 1   41    0   1       130   204    0        0      172      0      1.4      2
# 2   56    1   1       120   236    0        1      178      0      0.8      2
# 3   57    0   0       120   354    0        1      163      1      0.6      2
# 4   57    1   0       140   192    0        1      148      0      0.4      1
#
#    ca  thal  target
# 0   0     2       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     1       1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("heart.csv")
print("=========")
print("5 data pertama")
print("=========")
print(df.head())

print("==========")
print("5 data kebawah")
print("==========")
print(df.tail())
# Out:
# ...
# 5 data pertama
# ...
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1
# ...
# 5 data kebawah
# ...
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# ...

# %%
#variabel
nama="Data Science"
umur= 19
IPK=4.00
StatusMahasiswa=True

print ("=========")
print ("Nama :", nama)
print ("Umur :", umur)
print ("IPK :", IPK)
print ("Status :", StatusMahasiswa)
# Out:
# ...
# Nama : Data Science
# Umur : 19
# IPK : 4.0
# Status : True

# %%
#operator
a= 15
b= 7
print("penjumlahan =",a+b)
print("pengurangan =",a-b)
print("perkalian =",a*b)
print("pembagian =",a/b)
print("modulus =",a%b)
print("pangkat =",a**b)
# Out:
# penjumlahan = 22
# pengurangan = 8
# perkalian = 105
# pembagian = 2.142857142857143
# modulus = 1
# pangkat = 170859375

# %%
#perulangan (for & while)

#mengggunakan perulangan for

for i in range(1,6):
    print("perulangan ke-",i)

angka=1
while angka<=5:
    print("angka",angka)
    angka+=1
# Out:
# perulangan ke- 1
# perulangan ke- 2
# perulangan ke- 3
# perulangan ke- 4
# perulangan ke- 5
# angka 1
# angka 2
# angka 3
# angka 4
# angka 5

# %%
#fungsi

def hitung_luas_persegi(sisi):
  return sisi*sisi
print("Luas Persegi dengan sisi 4=",hitung_luas_persegi(4))
# Out:
# Luas Persegi dengan sisi 4= 16

# %%
# pervabangan if-else
nilai = 83
if nilai >=90:
  print("A")
elif nilai >=75:
  print("B")
elif nilai >=60:
  print("C")
else:
  print("tidak lulus")
# Out:
# B
